# %% [markdown]
# # Brent Oil Price Analysis - Exploratory Data Analysis
# ## Task 1: Data Loading, Cleaning, and EDA
#
# **Project:** Brent Oil Price Change Point Analysis
# **Organization:** Birhan Energies
# **Date:** February 8, 2026
# **Objective:** Analyze how geopolitical and economic events affect Brent crude oil prices
#
# ---
#
# ### Notebook Overview
# 1. Data Loading and Cleaning
# 2. Feature Engineering
# 3. Exploratory Data Analysis
# 4. Stationarity Testing
# 5. Volatility Analysis
# 6. Summary Statistics

# %% [markdown]
# ## 1. Setup and Imports

# %%
# Standard libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Statistical libraries
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.tsa.seasonal import seasonal_decompose
from scipy import stats
